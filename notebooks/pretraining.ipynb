# %% [markdown]
# # Imports

# %%
import os
import time

from PIL import Image

import torch
from torch.utils.data import random_split, DataLoader
from torch.optim import Adam

import torch.nn as nn
from torch.nn import CrossEntropyLoss

from torchvision import datasets, transforms

import timm

# %% [markdown]
# # Function Definitions

# %%
def train_model(epochs, model, criterion, optimizer, train_loader, valid_loader, device, save_dir, save_every, print_every):
    hist_train_loss = []
    hist_valid_loss = []
    hist_train_accs = []
    hist_valid_accs = []

    best_accuracy = 0.0

    iters_per_epoch = len(train_loader)

    for epoch in range(epochs):
        train_corr = 0
        valid_corr = 0
        batch_corr = 0

        for i, (X_train, y_train) in enumerate(train_loader):
            X_train, y_train = X_train.to(device), y_train.to(device)

            train_pred = model(X_train)
            train_loss = criterion(train_pred, y_train)

            train_predicted = torch.max(train_pred.data, 1)[1]
            batch_corr = (train_predicted == y_train).sum()
            train_corr += batch_corr

            optimizer.zero_grad()
            train_loss.backward()
            optimizer.step()

            if (i + 1) % print_every == 0:
                print(f'Iteration {i + 1}/{iters_per_epoch} complete; Loss: {train_loss.item()}')
                
            # checkpoint saving based on iterations
            if (i + 1) % save_every == 0:
                checkpoint_path = os.path.join(save_dir, f'epoch-{epoch}_iter-{i + 1}_checkpoint.pth')
                torch.save({
                    'epoch': epoch, 
                    'iteration': i + 1, 
                    'model_state_dict': model.state_dict(), 
                    'optimizer_state_dict': optimizer.state_dict(), 
                    'loss': train_loss.item()
                }, checkpoint_path)
                print(f'Checkpoint saved at {checkpoint_path} after {i + 1}/{iters_per_epoch} iterations of epoch {epoch}')

        train_accuracy = train_corr.item() / len(train_loader.dataset)

        hist_train_loss.append(train_loss.item())
        hist_train_accs.append(train_accuracy)

        with torch.no_grad():
            for X_valid, y_valid in valid_loader:
                X_valid, y_valid = X_valid.to(device), y_valid.to(device)

                valid_pred = model(X_valid)

                valid_predicted = torch.max(valid_pred.data, 1)[1]
                valid_corr += (valid_predicted == y_valid).sum()

        valid_accuracy = valid_corr.item() / len(valid_loader.dataset)
        valid_loss = criterion(valid_pred, y_valid)

        hist_valid_loss.append(valid_loss.item())
        hist_valid_accs.append(valid_accuracy)

        print(
            f'[epoch: {epoch}]\n', 
            f'- train loss: {train_loss.item():}, train accuracy: {train_accuracy}\n',
            f'- valid loss: {valid_loss.item()}, valid accuracy: {valid_accuracy}'
        )

        if valid_accuracy > best_accuracy:
            best_accuracy = valid_accuracy
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'hist_train_loss': hist_train_loss, 
                'hist_train_accs': hist_train_accs,
                'hist_valid_loss': hist_valid_loss, 
                'hist_valid_accs': hist_valid_accs
            }, os.path.join(save_dir, f'best_model.pth'))
            print(f'- New best model saves with accuracy {valid_accuracy:.4f}%')

# %% [markdown]
# # Main Excecution

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.cuda.manual_seed(42) if device.type == 'cuda' else torch.manual_seed(42)
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
# PREPARING THE DATASET

# data_path = '/scratch/ad5497/data/ftp.ebi.ac.uk/pub/databases/IDR/idr0016-wawer-bioactivecompoundprofiling/2016-01-19-screens-bbbc022'
data_path = '../data/pretraining-data'

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

dataset = datasets.ImageFolder(root=data_path, transform=transform)

dataset_indices_path = '../data/pretraining-dataset-indices.pth'
indices = torch.load(dataset_indices_path)

train_dataset = Subset(dataset, indices['train_indices'])
valid_dataset = Subset(dataset, indices['valid_indices'])
test_dataset = Subset(dataset, indices['test_indices'])

bs = 64
train_loader = DataLoader(train_dataset, batch_size=bs, shuffle=True, num_workers=8)
valid_loader = DataLoader(valid_dataset, batch_size=bs, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=bs, shuffle=False)

# %%
# CREATING AND TRAINING THE ViT MODEL

model = timm.create_model('vit_base_patch16_224', pretrained=False, num_classes=len(dataset.classes))
model = model.to(device)

epochs = 10

optimizer = Adam(model.parameters(), lr=1e-4)
criterion = CrossEntropyLoss()

save_dir = 'models'
os.makedirs(save_dir, exist_ok=True)
save_every = 90
print_every = 30

initial = time.time()
train_model(epochs, model, criterion, optimizer, train_loader, valid_loader, device, save_dir, save_every, print_every)
final = time.time()

print(f'Total time for {epochs} epochs of {len(train_loader)} iterations: {final - initial:.4f} seconds')
# Out:
# /home/ad5497/.local/lib/python3.11/site-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# Iteration 30/3780 complete; Loss: 1.5932883024215698
# Iteration 60/3780 complete; Loss: 1.5925735235214233
# Iteration 90/3780 complete; Loss: 1.4878363609313965
# Checkpoint saved at models/epoch-0_iter-90_checkpoint.pth after 90/3780 iterations of epoch 0
# Iteration 120/3780 complete; Loss: 0.9722626209259033
# Iteration 150/3780 complete; Loss: 1.0215811729431152
# Iteration 180/3780 complete; Loss: 0.9535061120986938
# Checkpoint saved at models/epoch-0_iter-180_checkpoint.pth after 180/3780 iterations of epoch 0
# Iteration 210/3780 complete; Loss: 0.8120726346969604
# Iteration 240/3780 complete; Loss: 1.5471727848052979
# Iteration 270/3780 complete; Loss: 0.9804590344429016
# Checkpoint saved at models/epoch-0_iter-270_checkpoint.pth after 270/3780 iterations of epoch 0
# Iteration 300/3780 complete; Loss: 1.0825762748718262
# Iteration 330/3780 complete; Loss: 0.9063102602958679
# Iteration 360/3780 complete; Loss: 0.8838392496109009
# Checkpoint saved at models/epoch-0_iter-360_checkpoint.pth after 360/3780 iterations of epoch 0
# Iteration 390/3780 complete; Loss: 0.7649361491203308
# Iteration 420/3780 complete; Loss: 0.7678480744361877
# Iteration 450/3780 complete; Loss: 0.8819326162338257
# Checkpoint saved at models/epoch-0_iter-450_checkpoint.pth after 450/3780 iterations of epoch 0
# Iteration 480/3780 complete; Loss: 0.7678180932998657
# Iteration 510/3780 complete; Loss: 0.7501710653305054
# Iteration 540/3780 complete; Loss: 0.7205962538719177
# Checkpoint saved at models/epoch-0_iter-540_checkpoint.pth after 540/3780 iterations of epoch 0
# Iteration 570/3780 complete; Loss: 0.6533095240592957
# Iteration 600/3780 complete; Loss: 0.679127037525177
# Iteration 630/3780 complete; Loss: 0.6926067471504211
# Checkpoint saved at models/epoch-0_iter-630_checkpoint.pth after 630/3780 iterations of epoch 0
# Iteration 660/3780 complete; Loss: 0.744040846824646
# Iteration 690/3780 complete; Loss: 0.78106689453125
# Iteration 720/3780 complete; Loss: 0.6131187677383423
# Checkpoint saved at models/epoch-0_iter-720_checkpoint.pth after 720/3780 iterations of epoch 0
# Iteration 750/3780 complete; Loss: 0.6646464467048645
# Iteration 780/3780 complete; Loss: 0.7542500495910645
# Iteration 810/3780 complete; Loss: 0.8121808171272278
# Checkpoint saved at models/epoch-0_iter-810_checkpoint.pth after 810/3780 iterations of epoch 0
# Iteration 840/3780 complete; Loss: 0.6655688285827637
# Iteration 870/3780 complete; Loss: 0.7736155986785889
# Iteration 900/3780 complete; Loss: 0.8630613088607788
# Checkpoint saved at models/epoch-0_iter-900_checkpoint.pth after 900/3780 iterations of epoch 0
# Iteration 930/3780 complete; Loss: 0.8178132176399231
# Iteration 960/3780 complete; Loss: 0.7732594609260559
# Iteration 990/3780 complete; Loss: 0.6386793255805969
# Checkpoint saved at models/epoch-0_iter-990_checkpoint.pth after 990/3780 iterations of epoch 0
# Iteration 1020/3780 complete; Loss: 0.8378686308860779
# Iteration 1050/3780 complete; Loss: 0.646869957447052
# Iteration 1080/3780 complete; Loss: 0.6793634295463562
# Checkpoint saved at models/epoch-0_iter-1080_checkpoint.pth after 1080/3780 iterations of epoch 0
# Iteration 1110/3780 complete; Loss: 0.683259129524231
# Iteration 1140/3780 complete; Loss: 0.7686586380004883
# Iteration 1170/3780 complete; Loss: 0.6699076890945435
# Checkpoint saved at models/epoch-0_iter-1170_checkpoint.pth after 1170/3780 iterations of epoch 0
# Iteration 1200/3780 complete; Loss: 0.6367706656455994
# Iteration 1230/3780 complete; Loss: 0.663257896900177
# Iteration 1260/3780 complete; Loss: 0.8364577889442444
# Checkpoint saved at models/epoch-0_iter-1260_checkpoint.pth after 1260/3780 iterations of epoch 0
# Iteration 1290/3780 complete; Loss: 0.8108744621276855
# Iteration 1320/3780 complete; Loss: 0.4908386468887329
# Iteration 1350/3780 complete; Loss: 0.6168892979621887
# Checkpoint saved at models/epoch-0_iter-1350_checkpoint.pth after 1350/3780 iterations of epoch 0
# Iteration 1380/3780 complete; Loss: 0.7066075801849365
# Iteration 1410/3780 complete; Loss: 0.6809902191162109
# Iteration 1440/3780 complete; Loss: 0.6300231218338013
# Checkpoint saved at models/epoch-0_iter-1440_checkpoint.pth after 1440/3780 iterations of epoch 0
# Iteration 1470/3780 complete; Loss: 0.7924320697784424
# Iteration 1500/3780 complete; Loss: 0.6813769936561584
# Iteration 1530/3780 complete; Loss: 0.6504237651824951
# Checkpoint saved at models/epoch-0_iter-1530_checkpoint.pth after 1530/3780 iterations of epoch 0
# Iteration 1560/3780 complete; Loss: 0.6136401295661926
# Iteration 1590/3780 complete; Loss: 0.6434590816497803
# Iteration 1620/3780 complete; Loss: 0.7304198741912842
# Checkpoint saved at models/epoch-0_iter-1620_checkpoint.pth after 1620/3780 iterations of epoch 0
# Iteration 1650/3780 complete; Loss: 0.6324232816696167
# Iteration 1680/3780 complete; Loss: 0.8243259787559509
# Iteration 1710/3780 complete; Loss: 0.7279704809188843
# Checkpoint saved at models/epoch-0_iter-1710_checkpoint.pth after 1710/3780 iterations of epoch 0
# Iteration 1740/3780 complete; Loss: 0.5812817215919495
# Iteration 1770/3780 complete; Loss: 0.8074865937232971
# Iteration 1800/3780 complete; Loss: 0.7796571850776672
# Checkpoint saved at models/epoch-0_iter-1800_checkpoint.pth after 1800/3780 iterations of epoch 0
# Iteration 1830/3780 complete; Loss: 0.7376149892807007
# Iteration 1860/3780 complete; Loss: 0.6767723560333252
# Iteration 1890/3780 complete; Loss: 0.5990578532218933
# Checkpoint saved at models/epoch-0_iter-1890_checkpoint.pth after 1890/3780 iterations of epoch 0
# Iteration 1920/3780 complete; Loss: 0.6611639261245728
# Iteration 1950/3780 complete; Loss: 0.6936947703361511
# Iteration 1980/3780 complete; Loss: 0.7199570536613464
# Checkpoint saved at models/epoch-0_iter-1980_checkpoint.pth after 1980/3780 iterations of epoch 0
# Iteration 2010/3780 complete; Loss: 0.7158610820770264
# Iteration 2040/3780 complete; Loss: 0.6344584226608276
# Iteration 2070/3780 complete; Loss: 0.7292704582214355
# Checkpoint saved at models/epoch-0_iter-2070_checkpoint.pth after 2070/3780 iterations of epoch 0
# Iteration 2100/3780 complete; Loss: 0.6823518872261047
# Iteration 2130/3780 complete; Loss: 0.6832324266433716
# Iteration 2160/3780 complete; Loss: 0.5727458596229553
# Checkpoint saved at models/epoch-0_iter-2160_checkpoint.pth after 2160/3780 iterations of epoch 0
# Iteration 2190/3780 complete; Loss: 0.8527765274047852
# Iteration 2220/3780 complete; Loss: 0.7409726977348328
# Iteration 2250/3780 complete; Loss: 0.7577375173568726
# Checkpoint saved at models/epoch-0_iter-2250_checkpoint.pth after 2250/3780 iterations of epoch 0
# Iteration 2280/3780 complete; Loss: 0.7777345776557922
# Iteration 2310/3780 complete; Loss: 0.7041798830032349
# Iteration 2340/3780 complete; Loss: 0.699115514755249
# Checkpoint saved at models/epoch-0_iter-2340_checkpoint.pth after 2340/3780 iterations of epoch 0
# Iteration 2370/3780 complete; Loss: 0.7260691523551941
# Iteration 2400/3780 complete; Loss: 0.7274773120880127
# Iteration 2430/3780 complete; Loss: 0.6836400628089905
# Checkpoint saved at models/epoch-0_iter-2430_checkpoint.pth after 2430/3780 iterations of epoch 0
# Iteration 2460/3780 complete; Loss: 0.7323746085166931
# Iteration 2490/3780 complete; Loss: 0.6058346033096313
# Iteration 2520/3780 complete; Loss: 0.7064365744590759
# Checkpoint saved at models/epoch-0_iter-2520_checkpoint.pth after 2520/3780 iterations of epoch 0
# Iteration 2550/3780 complete; Loss: 0.6547163724899292
# Iteration 2580/3780 complete; Loss: 0.6555366516113281
# Iteration 2610/3780 complete; Loss: 0.6280547976493835
# Checkpoint saved at models/epoch-0_iter-2610_checkpoint.pth after 2610/3780 iterations of epoch 0
# Iteration 2640/3780 complete; Loss: 0.7867507338523865
# Iteration 2670/3780 complete; Loss: 0.6855936646461487
# Iteration 2700/3780 complete; Loss: 0.7078589797019958
# Checkpoint saved at models/epoch-0_iter-2700_checkpoint.pth after 2700/3780 iterations of epoch 0
# Iteration 2730/3780 complete; Loss: 0.6259093284606934
# Iteration 2760/3780 complete; Loss: 0.5653350353240967
# Iteration 2790/3780 complete; Loss: 0.7883555293083191
# Checkpoint saved at models/epoch-0_iter-2790_checkpoint.pth after 2790/3780 iterations of epoch 0
# Iteration 2820/3780 complete; Loss: 0.6251409649848938
# Iteration 2850/3780 complete; Loss: 0.687548816204071
# Iteration 2880/3780 complete; Loss: 0.6066051125526428
# Checkpoint saved at models/epoch-0_iter-2880_checkpoint.pth after 2880/3780 iterations of epoch 0
# Iteration 2910/3780 complete; Loss: 0.7248943448066711
# Iteration 2940/3780 complete; Loss: 0.5535317659378052
# Iteration 2970/3780 complete; Loss: 0.7446346879005432
# Checkpoint saved at models/epoch-0_iter-2970_checkpoint.pth after 2970/3780 iterations of epoch 0
# Iteration 3000/3780 complete; Loss: 0.6580977439880371
# Iteration 3030/3780 complete; Loss: 0.5535749793052673
# Iteration 3060/3780 complete; Loss: 0.7355991005897522
# Checkpoint saved at models/epoch-0_iter-3060_checkpoint.pth after 3060/3780 iterations of epoch 0
# Iteration 3090/3780 complete; Loss: 0.6416454911231995
# Iteration 3120/3780 complete; Loss: 0.7992327213287354
# Iteration 3150/3780 complete; Loss: 0.6593214273452759
# Checkpoint saved at models/epoch-0_iter-3150_checkpoint.pth after 3150/3780 iterations of epoch 0
# Iteration 3180/3780 complete; Loss: 0.7786644101142883
# Iteration 3210/3780 complete; Loss: 0.7206387519836426
# Iteration 3240/3780 complete; Loss: 0.6702283620834351
# Checkpoint saved at models/epoch-0_iter-3240_checkpoint.pth after 3240/3780 iterations of epoch 0
# Iteration 3270/3780 complete; Loss: 0.6695887446403503
# Iteration 3300/3780 complete; Loss: 0.6249048113822937
# Iteration 3330/3780 complete; Loss: 0.5380440950393677
# Checkpoint saved at models/epoch-0_iter-3330_checkpoint.pth after 3330/3780 iterations of epoch 0
# Iteration 3360/3780 complete; Loss: 0.7139350771903992
# Iteration 3390/3780 complete; Loss: 0.5992156267166138
# Iteration 3420/3780 complete; Loss: 0.5155953764915466
# Checkpoint saved at models/epoch-0_iter-3420_checkpoint.pth after 3420/3780 iterations of epoch 0
# Iteration 3450/3780 complete; Loss: 0.6038016080856323
# Iteration 3480/3780 complete; Loss: 0.6234560012817383
# Iteration 3510/3780 complete; Loss: 0.7337583899497986
# Checkpoint saved at models/epoch-0_iter-3510_checkpoint.pth after 3510/3780 iterations of epoch 0
# Iteration 3540/3780 complete; Loss: 0.6117685437202454
# Iteration 3570/3780 complete; Loss: 0.5611667037010193
# Iteration 3600/3780 complete; Loss: 0.6937745213508606
# Checkpoint saved at models/epoch-0_iter-3600_checkpoint.pth after 3600/3780 iterations of epoch 0
# Iteration 3630/3780 complete; Loss: 0.7013248801231384
# Iteration 3660/3780 complete; Loss: 0.6564694046974182
# Iteration 3690/3780 complete; Loss: 0.6915419697761536
# Checkpoint saved at models/epoch-0_iter-3690_checkpoint.pth after 3690/3780 iterations of epoch 0
# Iteration 3720/3780 complete; Loss: 0.5575435161590576
# Iteration 3750/3780 complete; Loss: 0.5866662859916687
# Iteration 3780/3780 complete; Loss: 0.6842086315155029
# Checkpoint saved at models/epoch-0_iter-3780_checkpoint.pth after 3780/3780 iterations of epoch 0
